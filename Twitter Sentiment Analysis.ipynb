# %%
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
#import seaborn as sns
# %matplotlib inline

#Variables that contains the user credentials to access Twitter API 
access_token = #enter your access_token
access_secret = #enter your access_secret
consumer_key = #enter your consumer_key
consumer_secret = #enter your consumer_secret

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)

    # Return API with authentication:
    api = tweepy.API(auth)
    return api

# %%
# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name="narendramodi", count=200)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("5 recent tweets:\n")
for tweet in tweets[:5]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 200.
#
# 5 recent tweets:
#
# Working towards ensuring a better quality of life for 125 crore Indians. #SaafNiyatSahiVikas https://t.co/xRJcyLcPLB
#
# Tune in at 11 AM today. #MannKiBaat https://t.co/IskEE4fgOe
#
# Birthday greetings to my valued colleague @nitin_gadkari Ji. Nitin Ji has made a mark as an effective administrator… https://t.co/enn1g97eUI
#
# Tributes to our first Prime Minister, Pandit Jawaharlal Nehru on his death anniversary.
#
# Great enthusiasm at the rally in Cuttack. https://t.co/1N6uV4DmnN

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(5))
# Out:
#                                               Tweets
# 0  Working towards ensuring a better quality of l...
# 1  Tune in at 11 AM today. #MannKiBaat https://t....
# 2  Birthday greetings to my valued colleague @nit...
# 3  Tributes to our first Prime Minister, Pandit J...
# 4  Great enthusiasm at the rally in Cuttack. http...

# %%
data
# Out:
#                                                 Tweets
# 0    I am glad I could travel to all three regions ...
# 1    Inaugurated two vital projects which will bene...
# 2    At a programme in Jammu, laid the foundation s...
# 3    Embracing AI and Block Chain Technology would ...
# 4    Need of the hour is to invigorate our agricult...
# 5    As my young friends embark on a new phase of t...
# 6    Joined the convocation ceremony of the Sher-e-...
# 7    Today I unveiled a plaque which marks the comm...
# 8    In Leh, joined the Closing Ceremony of the Bir...
# 9    Earlier today, visited the enchanting land of ...
# 10   कश्मीरियत के अटल जी भी कायल रहे हैं और इसी कश्...
# 11   Jammu and Kashmir deserves topmost quality of ...
# 12   Tourism is vital to Jammu and Kashmir’s develo...
# 13   Laid the foundation stone for the Srinagar Rin...
# 14   Honoured to have dedicated the Kishanganga Hyd...
# 15   I am glad I got the opportunity to visit Jammu...
# 16   I thank the wonderful people of Leh for the wa...
# 17   Birthday greetings to Mr. Lal Thanhawla, the C...
# 18   Birthday greetings to my valued colleague and ...
# 19   Spoke to our former Prime Minister Shri HD Dev...
# 20   Ramzan greetings to everyone. We recall the pi...
# 21   سبھی کو مقدس ماہِ رمضان کی مبارکباد ! ہم پیغمب...
# 22   I congratulate my sisters and brothers of Jhar...
# 23   We are committed to the welfare of our farmers...
# 24   The proposed National Institute of Mental Heal...
# 25   A decision that will benefit the people of Noi...
# 26   Greetings to the people of Sikkim on their Sta...
# 27   Anguished by the capsizing of a boat in Andhra...
# 28   Addressed BJP Karyakartas earlier this evening...
# 29   I spoke to UP CM Yogi Adityanath Ji regarding ...
# ..                                                 ...
# 170  Thank you Karnataka. Overwhelmed by the suppor...
# 171  Tomorrow morning, will be interacting with @BJ...
# 172  BJP is committed towards creating a Swachh, Su...
# 173  Congress’ dislike for the Indian Army and the ...
# 174  Congress can win Gold Medals in corruption, te...
# 175  Congress attempted to change Bengaluru, a city...
# 176  Joined the huge public meeting in Bengaluru. I...
# 177  After massive rallies in Kalaburagi and Ballar...
# 178  Thank you Ballari for the phenomenal support. ...
# 179  Wherever @BJP4India is serving, the people are...
# 180  The NDA Government will continuously work for ...
# 181  Nobody can forget the manner in which the Cong...
# 182  For the last five years, the Karnataka Governm...
# 183  Have a look at these images from the rally in ...
# 184  ಸರಕಾರ ಬದಲಿಸಿ, ಬಿಜೆಪಿ ಗೆಲ್ಲಿಸಿ @BJP4Karnataka h...
# 185  ಬಳ್ಳಾರಿಯಲ್ಲಿ ಬೃಹತ್ ಸಮಾವೇಶ ಉದ್ದೇಶಿಸಿ ಮಾತನಾಡಿದೆ....
# 186  ಬಿಜೆಪಿ ಅಧಿಕಾರಕ್ಕೆ ಬಂದಾಗಲೆಲ್ಲ ಶ್ರೀಸಾಮಾನ್ಯರ ಏಳಿಗ...
# 187  ಕಲಬುರಗಿ ಸಮಾವೇಶದಲ್ಲಿ ಜನರ ಉತ್ಸಾಹ ಅದ್ಭುತವಾಗಿತ್ತು....
# 188  Flexibility is the hallmark of Vakrasana. Be i...
# 189  I would once again like to appreciate the proa...
# 190  I applaud all those who have been working tire...
# 191  A free press makes a stronger democracy! Today...
# 192  Will be addressing three rallies across Karnat...
# 193  Greetings to Jharkhand’s hardworking Chief Min...
# 194  Birthday wishes to @umasribharti Ji. Uma Ji’s ...
# 195  Gandhi Ji’s 150th birth anniversary is a perfe...
# 196  Mahatma Gandhi gave his life for the nation. H...
# 197  Rashtrapati Ji chaired the first meeting of th...
# 198  Continuing my interactions via the NaMo App, I...
# 199  The Congress Government in Karnataka has compl...
#
# [200 rows x 1 columns]

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'extended_entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1000590452117065729
# 2018-05-27 04:12:08
# Twitter for iPhone
# 3333
# 943
# None
# None
# {'user_mentions': [], 'hashtags': [{'indices': [73, 92], 'text': 'SaafNiyatSahiVikas'}], 'symbols': [], 'urls': [], 'media': [{'media_url_https': 'https://pbs.twimg.com/media/DeLPpmyV4AAxF1F.jpg', 'url': 'https://t.co/xRJcyLcPLB', 'id_str': '1000590380922953728', 'sizes': {'large': {'w': 1280, 'resize': 'fit', 'h': 969}, 'thumb': {'w': 150, 'resize': 'crop', 'h': 150}, 'medium': {'w': 1200, 'resize': 'fit', 'h': 908}, 'small': {'w': 680, 'resize': 'fit', 'h': 515}}, 'type': 'photo', 'display_url': 'pic.twitter.com/xRJcyLcPLB', 'indices': [93, 116], 'id': 1000590380922953728, 'expanded_url': 'https://twitter.com/narendramodi/status/1000590452117065729/photo/1', 'media_url': 'http://pbs.twimg.com/media/DeLPpmyV4AAxF1F.jpg'}]}

# %%
# We add relevant data:
data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID']   = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

# %%
# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets  len  \
# 0  Working towards ensuring a better quality of l...  116
# 1  Tune in at 11 AM today. #MannKiBaat https://t....   59
# 2  Birthday greetings to my valued colleague @nit...  140
# 3  Tributes to our first Prime Minister, Pandit J...   87
# 4  Great enthusiasm at the rally in Cuttack. http...   65
# 5  I congratulate all my young friends who have p...  140
# 6  Today in Cuttack I gave the people of India an...  140
# 7  Odisha Government has misled the people of the...  139
# 8  Reforms like neem coated urea, soil health car...  140
# 9  We have transformed systems to ensure better q...  139
#
#                     ID                Date              Source  Likes   RTs
# 0  1000590452117065729 2018-05-27 04:12:08  Twitter for iPhone   3333   943
# 1  1000559848008765440 2018-05-27 02:10:31  Twitter for iPhone   3385   802
# 2  1000558965862756353 2018-05-27 02:07:01  Twitter for iPhone   7617  1626
# 3  1000557850068832256 2018-05-27 02:02:35  Twitter for iPhone   7802  1222
# 4  1000428360718266368 2018-05-26 17:28:02        Media Studio   5704  1395
# 5  1000424599207768065 2018-05-26 17:13:06  Twitter Web Client  11629  1992
# 6  1000424064287207424 2018-05-26 17:10:58  Twitter Web Client   5111  1378
# 7  1000423539307089925 2018-05-26 17:08:53        Media Studio   4770  1278
# 8  1000422788132425729 2018-05-26 17:05:54  Twitter Web Client   6151  1697
# 9  1000420933771837445 2018-05-26 16:58:32  Twitter Web Client   6283  1635

# %%
# We extract the mean of lenghts:
mean = np.mean(data['len'])

print("The lenght's average in tweets: {}".format(mean))
# Out:
# The lenght's average in tweets: 130.715

# %%
# We extract the tweet with more FAVs and more RTs:

fav_max = np.max(data['Likes'])
rt_max  = np.max(data['RTs'])

fav = data[data.Likes == fav_max].index[0]
rt  = data[data.RTs == rt_max].index[0]

# Max FAVs:
print("The tweet with more likes is: \n{}".format(data['Tweets'][fav]))
print("Number of likes: {}".format(fav_max))
print("{} characters.\n".format(data['len'][fav]))

# Max RTs:
print("The tweet with more retweets is: \n{}".format(data['Tweets'][rt]))
print("Number of retweets: {}".format(rt_max))
print("{} characters.\n".format(data['len'][rt]))
# Out:
# The tweet with more likes is:
# I thank my sisters and brothers of Karnataka for steadfastly supporting the BJP’s development agenda and making BJP… https://t.co/Pi5aJ6a0K3
# Number of likes: 45136
# 140 characters.
#
# The tweet with more retweets is:
# I thank my sisters and brothers of Karnataka for steadfastly supporting the BJP’s development agenda and making BJP… https://t.co/Pi5aJ6a0K3
# Number of retweets: 10415
# 140 characters.

# %%
# We create time series for data:

tlen = pd.Series(data=data['len'].values, index=data['Date'])
tfav = pd.Series(data=data['Likes'].values, index=data['Date'])
tret = pd.Series(data=data['RTs'].values, index=data['Date'])

# %%
tlen.plot(figsize=(16,4), color='r');

# %%
# Likes vs retweets visualization:
tfav.plot(figsize=(16,4), label="Likes", legend=True)
tret.plot(figsize=(16,4), label="Retweets", legend=True);

# %%
# We obtain all possible sources:
sources = []
for source in data['Source']:
    if source not in sources:
        sources.append(source)

# We print sources list:
print("Creation of content sources:")
for source in sources:
    print("* {}".format(source))
# Out:
# Creation of content sources:
# * Twitter for iPhone
# * Media Studio
# * Twitter Web Client

# %%
# We create a numpy vector mapped to labels:
percent = np.zeros(len(sources))

for source in data['Source']:
    for index in range(len(sources)):
        if source == sources[index]:
            percent[index] += 1
            pass

percent /= 100

# Pie chart:
pie_chart = pd.Series(percent, index=sources, name='Sources')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6));

# %%
from textblob import TextBlob
import re

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
# We create a column with the result of the analysis:
data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])

# We display the updated dataframe with the new column:
display(data.head(10))
print(data.SA.unique())
# Out:
#                                               Tweets  len  \
# 0  Working towards ensuring a better quality of l...  116
# 1  Tune in at 11 AM today. #MannKiBaat https://t....   59
# 2  Birthday greetings to my valued colleague @nit...  140
# 3  Tributes to our first Prime Minister, Pandit J...   87
# 4  Great enthusiasm at the rally in Cuttack. http...   65
# 5  I congratulate all my young friends who have p...  140
# 6  Today in Cuttack I gave the people of India an...  140
# 7  Odisha Government has misled the people of the...  139
# 8  Reforms like neem coated urea, soil health car...  140
# 9  We have transformed systems to ensure better q...  139
#
#                     ID                Date              Source  Likes   RTs  \
# 0  1000590452117065729 2018-05-27 04:12:08  Twitter for iPhone   3333   943
# 1  1000559848008765440 2018-05-27 02:10:31  Twitter for iPhone   3385   802
# 2  1000558965862756353 2018-05-27 02:07:01  Twitter for iPhone   7617  1626
# 3  1000557850068832256 2018-05-27 02:02:35  Twitter for iPhone   7802  1222
# 4  1000428360718266368 2018-05-26 17:28:02        Media Studio   5704  1395
# 5  1000424599207768065 2018-05-26 17:13:06  Twitter Web Client  11629  1992
# 6  1000424064287207424 2018-05-26 17:10:58  Twitter Web Client   5111  1378
# 7  1000423539307089925 2018-05-26 17:08:53        Media Studio   4770  1278
# 8  1000422788132425729 2018-05-26 17:05:54  Twitter Web Client   6151  1697
# 9  1000420933771837445 2018-05-26 16:58:32  Twitter Web Client   6283  1635
#
#    SA
# 0   1
# 1   0
# 2   1
# 3   1
# 4   1
# 5   1
# 6   0
# 7   0
# 8   0
# 9   1
# [ 1  0 -1]

# %%
# We construct lists with classified tweets:

pos_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] > 0]
neu_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] == 0]
neg_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] < 0]

# %%
# We print percentages:

print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(data['Tweets'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(data['Tweets'])))
print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(data['Tweets'])))
# Out:
# Percentage of positive tweets: 45.5%
# Percentage of neutral tweets: 47.5%
# Percentage de negative tweets: 7.0%

# %%
data.to_csv("Tweet_data.csv")
